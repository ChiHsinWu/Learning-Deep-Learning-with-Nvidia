# %% [markdown]
# 程式4-6

# %%
import numpy as np
from tensorflow.keras.applications import resnet50
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.resnet50 import \
    decode_predictions
import matplotlib.pyplot as plt
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %% [markdown]
# 程式4-7

# %%
#載入影像並轉換為 4D 陣列
image = load_img('/content/dog.jpg', target_size=(224, 224))
image_np = img_to_array(image)
image_np = np.expand_dims(image_np, axis=0)

# %% [markdown]
# 程式4-8

# %%
# 載入預訓練好的模型
model = resnet50.ResNet50(weights='imagenet')
# 將輸入資料做標準化
X = resnet50.preprocess_input(image_np.copy())
# 進行預測
y = model.predict(X)
predicted_labels = decode_predictions(y)
print('predictions = ', predicted_labels)

# 顯示預測結果
plt.imshow(np.uint8(image_np[0]))
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 [==============================] - 1s 0us/step
# 1/1 [==============================] - 2s 2s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step
# predictions =  [[('n02123045', 'tabby', 0.17342806), ('n02124075', 'Egyptian_cat', 0.11423237), ('n02870880', 'bookcase', 0.09173613), ('n03793489', 'mouse', 0.07806391), ('n03085013', 'computer_keyboard', 0.06224881)]]
