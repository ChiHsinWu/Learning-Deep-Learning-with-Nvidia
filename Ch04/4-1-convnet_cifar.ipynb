# %% [markdown]
# 程式4-1

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
import numpy as np
import logging
tf.get_logger().setLevel(logging.ERROR)

EPOCHS = 128
BATCH_SIZE = 32

# 載入 CIFAR-10 資料集
cifar_dataset = keras.datasets.cifar10
(train_images, train_labels), (test_images,
    test_labels) = cifar_dataset.load_data()

# 將資料集做標準化處理
mean = np.mean(train_images)
stddev = np.std(train_images)
train_images = (train_images - mean) / stddev
test_images = (test_images - mean) / stddev
print('mean: ', mean)
print('stddev: ', stddev)

# 將標籤轉換為 one-hot 格式
train_labels = to_categorical(train_labels,
                              num_classes=10)
test_labels = to_categorical(test_labels,
                             num_classes=10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step
# mean:  120.70756512369792
# stddev:  64.1500758911213

# %% [markdown]
# 程式4-2

# %%
# 在模型中加入雙卷積層與一密集層
model = Sequential()
model.add(Conv2D(64, (5, 5), strides=(2,2),
                 activation='relu',
                 input_shape=(32, 32, 3),
                 kernel_initializer='he_normal',
                 bias_initializer='zeros'))
model.add(Conv2D(64, (3, 3), strides=(2,2),
                 activation='relu', padding='same',
                 kernel_initializer='he_normal',
                 bias_initializer='zeros'))
model.add(Flatten())
model.add(Dense(10, activation='softmax',
                kernel_initializer='glorot_uniform',
                bias_initializer='zeros'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam', metrics =['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 14, 14, 64)        4864
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)          36928
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 10)                31370
#
# =================================================================
# Total params: 73,162
# Trainable params: 73,162
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 程式4-3

# %%
history = model.fit(
    train_images, train_labels, validation_data =
    (test_images, test_labels), epochs=EPOCHS,
    batch_size=BATCH_SIZE, verbose=2, shuffle=True)
# Out:
# Epoch 1/128
# 1563/1563 - 37s - loss: 1.4049 - accuracy: 0.5055 - val_loss: 1.1650 - val_accuracy: 0.5904 - 37s/epoch - 24ms/step
# Epoch 2/128
# 1563/1563 - 38s - loss: 1.0494 - accuracy: 0.6359 - val_loss: 1.0408 - val_accuracy: 0.6400 - 38s/epoch - 24ms/step
# Epoch 3/128
# 1563/1563 - 37s - loss: 0.9019 - accuracy: 0.6882 - val_loss: 1.0135 - val_accuracy: 0.6491 - 37s/epoch - 24ms/step
# Epoch 4/128
# 1563/1563 - 35s - loss: 0.8050 - accuracy: 0.7238 - val_loss: 0.9988 - val_accuracy: 0.6603 - 35s/epoch - 22ms/step
# Epoch 5/128
# 1563/1563 - 34s - loss: 0.7243 - accuracy: 0.7496 - val_loss: 1.0182 - val_accuracy: 0.6598 - 34s/epoch - 22ms/step
# Epoch 6/128
# 1563/1563 - 35s - loss: 0.6583 - accuracy: 0.7710 - val_loss: 1.0323 - val_accuracy: 0.6661 - 35s/epoch - 23ms/step
# Epoch 7/128
# 1563/1563 - 34s - loss: 0.6044 - accuracy: 0.7897 - val_loss: 1.0867 - val_accuracy: 0.6567 - 34s/epoch - 22ms/step
# Epoch 8/128
# 1563/1563 - 37s - loss: 0.5568 - accuracy: 0.8061 - val_loss: 1.1761 - val_accuracy: 0.6548 - 37s/epoch - 24ms/step
# Epoch 9/128
# 1563/1563 - 35s - loss: 0.5128 - accuracy: 0.8202 - val_loss: 1.2041 - val_accuracy: 0.6614 - 35s/epoch - 22ms/step
# Epoch 10/128
# 1563/1563 - 39s - loss: 0.4763 - accuracy: 0.8318 - val_loss: 1.2366 - val_accuracy: 0.6598 - 39s/epoch - 25ms/step
# Epoch 11/128
# 1563/1563 - 33s - loss: 0.4443 - accuracy: 0.8441 - val_loss: 1.2816 - val_accuracy: 0.6539 - 33s/epoch - 21ms/step
# Epoch 12/128
# 1563/1563 - 38s - loss: 0.4094 - accuracy: 0.8548 - val_loss: 1.4165 - val_accuracy: 0.6457 - 38s/epoch - 24ms/step
# Epoch 13/128
# 1563/1563 - 35s - loss: 0.3871 - accuracy: 0.8625 - val_loss: 1.4759 - val_accuracy: 0.6394 - 35s/epoch - 23ms/step
# Epoch 14/128
# 1563/1563 - 36s - loss: 0.3646 - accuracy: 0.8698 - val_loss: 1.5187 - val_accuracy: 0.6410 - 36s/epoch - 23ms/step
# Epoch 15/128
# 1563/1563 - 34s - loss: 0.3386 - accuracy: 0.8788 - val_loss: 1.5883 - val_accuracy: 0.6478 - 34s/epoch - 22ms/step
# Epoch 16/128
# 1563/1563 - 38s - loss: 0.3197 - accuracy: 0.8848 - val_loss: 1.6485 - val_accuracy: 0.6450 - 38s/epoch - 24ms/step
# Epoch 17/128
# 1563/1563 - 35s - loss: 0.3024 - accuracy: 0.8921 - val_loss: 1.7660 - val_accuracy: 0.6407 - 35s/epoch - 22ms/step
# Epoch 18/128
# 1563/1563 - 38s - loss: 0.2817 - accuracy: 0.8991 - val_loss: 1.8113 - val_accuracy: 0.6428 - 38s/epoch - 24ms/step
# Epoch 19/128
# 1563/1563 - 35s - loss: 0.2670 - accuracy: 0.9038 - val_loss: 1.8781 - val_accuracy: 0.6438 - 35s/epoch - 22ms/step
# Epoch 20/128
# 1563/1563 - 37s - loss: 0.2522 - accuracy: 0.9091 - val_loss: 2.0457 - val_accuracy: 0.6327 - 37s/epoch - 23ms/step
# Epoch 21/128
# 1563/1563 - 36s - loss: 0.2400 - accuracy: 0.9123 - val_loss: 2.1162 - val_accuracy: 0.6346 - 36s/epoch - 23ms/step
# Epoch 22/128
# 1563/1563 - 35s - loss: 0.2398 - accuracy: 0.9129 - val_loss: 2.1710 - val_accuracy: 0.6373 - 35s/epoch - 22ms/step
# Epoch 23/128
# 1563/1563 - 34s - loss: 0.2186 - accuracy: 0.9214 - val_loss: 2.2778 - val_accuracy: 0.6257 - 34s/epoch - 22ms/step
# Epoch 24/128
# 1563/1563 - 38s - loss: 0.2147 - accuracy: 0.9220 - val_loss: 2.2996 - val_accuracy: 0.6259 - 38s/epoch - 24ms/step
# Epoch 25/128
# 1563/1563 - 35s - loss: 0.2111 - accuracy: 0.9248 - val_loss: 2.4452 - val_accuracy: 0.6322 - 35s/epoch - 23ms/step
# Epoch 26/128
# 1563/1563 - 35s - loss: 0.1970 - accuracy: 0.9292 - val_loss: 2.5374 - val_accuracy: 0.6254 - 35s/epoch - 23ms/step
# Epoch 27/128
# 1563/1563 - 34s - loss: 0.1900 - accuracy: 0.9319 - val_loss: 2.6535 - val_accuracy: 0.6246 - 34s/epoch - 22ms/step
# Epoch 28/128
# 1563/1563 - 36s - loss: 0.1931 - accuracy: 0.9311 - val_loss: 2.8484 - val_accuracy: 0.6149 - 36s/epoch - 23ms/step
# Epoch 29/128
# 1563/1563 - 36s - loss: 0.1829 - accuracy: 0.9339 - val_loss: 2.8036 - val_accuracy: 0.6309 - 36s/epoch - 23ms/step
# Epoch 30/128
# 1563/1563 - 36s - loss: 0.1754 - accuracy: 0.9378 - val_loss: 2.9319 - val_accuracy: 0.6319 - 36s/epoch - 23ms/step
# Epoch 31/128
# 1563/1563 - 35s - loss: 0.1699 - accuracy: 0.9391 - val_loss: 2.9765 - val_accuracy: 0.6256 - 35s/epoch - 22ms/step
# Epoch 32/128
# 1563/1563 - 35s - loss: 0.1704 - accuracy: 0.9401 - val_loss: 3.0884 - val_accuracy: 0.6160 - 35s/epoch - 23ms/step
# Epoch 33/128
# 1563/1563 - 38s - loss: 0.1619 - accuracy: 0.9424 - val_loss: 3.1167 - val_accuracy: 0.6344 - 38s/epoch - 24ms/step
# Epoch 34/128
# 1563/1563 - 36s - loss: 0.1664 - accuracy: 0.9424 - val_loss: 3.2396 - val_accuracy: 0.6275 - 36s/epoch - 23ms/step
# Epoch 35/128
# 1563/1563 - 37s - loss: 0.1679 - accuracy: 0.9408 - val_loss: 3.3393 - val_accuracy: 0.6204 - 37s/epoch - 24ms/step
# Epoch 36/128
# 1563/1563 - 34s - loss: 0.1582 - accuracy: 0.9470 - val_loss: 3.3942 - val_accuracy: 0.6230 - 34s/epoch - 22ms/step
# Epoch 37/128
# 1563/1563 - 35s - loss: 0.1568 - accuracy: 0.9466 - val_loss: 3.4372 - val_accuracy: 0.6250 - 35s/epoch - 22ms/step
# Epoch 38/128
# 1563/1563 - 33s - loss: 0.1608 - accuracy: 0.9463 - val_loss: 3.7032 - val_accuracy: 0.6205 - 33s/epoch - 21ms/step
# Epoch 39/128
# 1563/1563 - 34s - loss: 0.1551 - accuracy: 0.9474 - val_loss: 3.5910 - val_accuracy: 0.6238 - 34s/epoch - 22ms/step
# Epoch 40/128
# 1563/1563 - 34s - loss: 0.1536 - accuracy: 0.9488 - val_loss: 3.7270 - val_accuracy: 0.6282 - 34s/epoch - 22ms/step
# Epoch 41/128
# 1563/1563 - 35s - loss: 0.1579 - accuracy: 0.9486 - val_loss: 3.7364 - val_accuracy: 0.6299 - 35s/epoch - 23ms/step
# Epoch 42/128
# 1563/1563 - 36s - loss: 0.1493 - accuracy: 0.9496 - val_loss: 3.8473 - val_accuracy: 0.6274 - 36s/epoch - 23ms/step
# Epoch 43/128
# 1563/1563 - 33s - loss: 0.1430 - accuracy: 0.9523 - val_loss: 3.8966 - val_accuracy: 0.6260 - 33s/epoch - 21ms/step
# Epoch 44/128
# 1563/1563 - 32s - loss: 0.1495 - accuracy: 0.9519 - val_loss: 4.1140 - val_accuracy: 0.6295 - 32s/epoch - 21ms/step
# Epoch 45/128
# 1563/1563 - 36s - loss: 0.1503 - accuracy: 0.9517 - val_loss: 4.1645 - val_accuracy: 0.6204 - 36s/epoch - 23ms/step
# Epoch 46/128
# 1563/1563 - 34s - loss: 0.1457 - accuracy: 0.9533 - val_loss: 4.1097 - val_accuracy: 0.6270 - 34s/epoch - 22ms/step
# Epoch 47/128
# 1563/1563 - 34s - loss: 0.1538 - accuracy: 0.9513 - val_loss: 4.3466 - val_accuracy: 0.6189 - 34s/epoch - 22ms/step
# Epoch 48/128
# 1563/1563 - 34s - loss: 0.1463 - accuracy: 0.9538 - val_loss: 4.4341 - val_accuracy: 0.6208 - 34s/epoch - 22ms/step
# Epoch 49/128
# 1563/1563 - 33s - loss: 0.1352 - accuracy: 0.9570 - val_loss: 4.4663 - val_accuracy: 0.6237 - 33s/epoch - 21ms/step
# Epoch 50/128
# 1563/1563 - 36s - loss: 0.1426 - accuracy: 0.9560 - val_loss: 4.5007 - val_accuracy: 0.6264 - 36s/epoch - 23ms/step
# Epoch 51/128
# 1563/1563 - 35s - loss: 0.1508 - accuracy: 0.9537 - val_loss: 4.6463 - val_accuracy: 0.6182 - 35s/epoch - 22ms/step
# Epoch 52/128
# 1563/1563 - 34s - loss: 0.1427 - accuracy: 0.9559 - val_loss: 4.6734 - val_accuracy: 0.6232 - 34s/epoch - 22ms/step
# Epoch 53/128
# 1563/1563 - 33s - loss: 0.1392 - accuracy: 0.9568 - val_loss: 4.7054 - val_accuracy: 0.6236 - 33s/epoch - 21ms/step
# Epoch 54/128
# 1563/1563 - 36s - loss: 0.1346 - accuracy: 0.9583 - val_loss: 4.7154 - val_accuracy: 0.6169 - 36s/epoch - 23ms/step
# Epoch 55/128
# 1563/1563 - 35s - loss: 0.1410 - accuracy: 0.9585 - val_loss: 5.0216 - val_accuracy: 0.6279 - 35s/epoch - 22ms/step
# Epoch 56/128
# 1563/1563 - 33s - loss: 0.1437 - accuracy: 0.9562 - val_loss: 4.8602 - val_accuracy: 0.6280 - 33s/epoch - 21ms/step
# Epoch 57/128
# 1563/1563 - 33s - loss: 0.1376 - accuracy: 0.9587 - val_loss: 4.8475 - val_accuracy: 0.6264 - 33s/epoch - 21ms/step
# Epoch 58/128
# 1563/1563 - 36s - loss: 0.1295 - accuracy: 0.9610 - val_loss: 5.0078 - val_accuracy: 0.6142 - 36s/epoch - 23ms/step
# Epoch 59/128
# 1563/1563 - 35s - loss: 0.1476 - accuracy: 0.9572 - val_loss: 5.1981 - val_accuracy: 0.6199 - 35s/epoch - 22ms/step
# Epoch 60/128
# 1563/1563 - 33s - loss: 0.1431 - accuracy: 0.9588 - val_loss: 5.2277 - val_accuracy: 0.6193 - 33s/epoch - 21ms/step
# Epoch 61/128
# 1563/1563 - 33s - loss: 0.1429 - accuracy: 0.9594 - val_loss: 5.3279 - val_accuracy: 0.6236 - 33s/epoch - 21ms/step
# Epoch 62/128
# 1563/1563 - 34s - loss: 0.1301 - accuracy: 0.9616 - val_loss: 5.4365 - val_accuracy: 0.6219 - 34s/epoch - 22ms/step
# Epoch 63/128
# 1563/1563 - 35s - loss: 0.1337 - accuracy: 0.9621 - val_loss: 5.5355 - val_accuracy: 0.6183 - 35s/epoch - 23ms/step
# Epoch 64/128
# 1563/1563 - 34s - loss: 0.1399 - accuracy: 0.9605 - val_loss: 5.5636 - val_accuracy: 0.6276 - 34s/epoch - 22ms/step
# Epoch 65/128
# 1563/1563 - 33s - loss: 0.1488 - accuracy: 0.9604 - val_loss: 5.5077 - val_accuracy: 0.6261 - 33s/epoch - 21ms/step
# Epoch 66/128
# 1563/1563 - 33s - loss: 0.1248 - accuracy: 0.9643 - val_loss: 5.7090 - val_accuracy: 0.6249 - 33s/epoch - 21ms/step
# Epoch 67/128
# 1563/1563 - 37s - loss: 0.1423 - accuracy: 0.9608 - val_loss: 5.7700 - val_accuracy: 0.6269 - 37s/epoch - 24ms/step
# Epoch 68/128
# 1563/1563 - 36s - loss: 0.1381 - accuracy: 0.9628 - val_loss: 5.8402 - val_accuracy: 0.6253 - 36s/epoch - 23ms/step
# Epoch 69/128
# 1563/1563 - 35s - loss: 0.1442 - accuracy: 0.9608 - val_loss: 6.0241 - val_accuracy: 0.6149 - 35s/epoch - 23ms/step
# Epoch 70/128
# 1563/1563 - 33s - loss: 0.1348 - accuracy: 0.9633 - val_loss: 6.0428 - val_accuracy: 0.6228 - 33s/epoch - 21ms/step
# Epoch 71/128
# 1563/1563 - 34s - loss: 0.1289 - accuracy: 0.9648 - val_loss: 6.2524 - val_accuracy: 0.6241 - 34s/epoch - 22ms/step
# Epoch 72/128
# 1563/1563 - 34s - loss: 0.1424 - accuracy: 0.9621 - val_loss: 6.1936 - val_accuracy: 0.6238 - 34s/epoch - 22ms/step
# Epoch 73/128
# 1563/1563 - 34s - loss: 0.1339 - accuracy: 0.9653 - val_loss: 6.2694 - val_accuracy: 0.6265 - 34s/epoch - 22ms/step
# Epoch 74/128
# 1563/1563 - 34s - loss: 0.1371 - accuracy: 0.9642 - val_loss: 6.4342 - val_accuracy: 0.6217 - 34s/epoch - 22ms/step
# Epoch 75/128
# 1563/1563 - 33s - loss: 0.1280 - accuracy: 0.9659 - val_loss: 6.3706 - val_accuracy: 0.6165 - 33s/epoch - 21ms/step
# Epoch 76/128
# 1563/1563 - 35s - loss: 0.1565 - accuracy: 0.9618 - val_loss: 6.5170 - val_accuracy: 0.6314 - 35s/epoch - 22ms/step
# Epoch 77/128
# 1563/1563 - 36s - loss: 0.1339 - accuracy: 0.9660 - val_loss: 6.7051 - val_accuracy: 0.6238 - 36s/epoch - 23ms/step
# Epoch 78/128
# 1563/1563 - 36s - loss: 0.1296 - accuracy: 0.9666 - val_loss: 6.7326 - val_accuracy: 0.6298 - 36s/epoch - 23ms/step
# Epoch 79/128
# 1563/1563 - 36s - loss: 0.1416 - accuracy: 0.9645 - val_loss: 6.8536 - val_accuracy: 0.6211 - 36s/epoch - 23ms/step
# Epoch 80/128
# 1563/1563 - 36s - loss: 0.1339 - accuracy: 0.9666 - val_loss: 7.0818 - val_accuracy: 0.6184 - 36s/epoch - 23ms/step
# Epoch 81/128
# 1563/1563 - 33s - loss: 0.1398 - accuracy: 0.9657 - val_loss: 6.8185 - val_accuracy: 0.6184 - 33s/epoch - 21ms/step
# Epoch 82/128
# 1563/1563 - 33s - loss: 0.1379 - accuracy: 0.9648 - val_loss: 6.9537 - val_accuracy: 0.6259 - 33s/epoch - 21ms/step
# Epoch 83/128
# 1563/1563 - 33s - loss: 0.1374 - accuracy: 0.9674 - val_loss: 7.1723 - val_accuracy: 0.6246 - 33s/epoch - 21ms/step
# Epoch 84/128
# 1563/1563 - 34s - loss: 0.1358 - accuracy: 0.9672 - val_loss: 7.3317 - val_accuracy: 0.6192 - 34s/epoch - 22ms/step
# Epoch 85/128
# 1563/1563 - 35s - loss: 0.1310 - accuracy: 0.9681 - val_loss: 7.3186 - val_accuracy: 0.6275 - 35s/epoch - 23ms/step
# Epoch 86/128
# 1563/1563 - 34s - loss: 0.1384 - accuracy: 0.9671 - val_loss: 7.3726 - val_accuracy: 0.6198 - 34s/epoch - 22ms/step
# Epoch 87/128
# 1563/1563 - 33s - loss: 0.1435 - accuracy: 0.9674 - val_loss: 7.4380 - val_accuracy: 0.6198 - 33s/epoch - 21ms/step
# Epoch 88/128
# 1563/1563 - 33s - loss: 0.1432 - accuracy: 0.9669 - val_loss: 7.4519 - val_accuracy: 0.6288 - 33s/epoch - 21ms/step
# Epoch 89/128
# 1563/1563 - 35s - loss: 0.1309 - accuracy: 0.9689 - val_loss: 7.8134 - val_accuracy: 0.6250 - 35s/epoch - 23ms/step
# Epoch 90/128
# 1563/1563 - 33s - loss: 0.1416 - accuracy: 0.9671 - val_loss: 7.6555 - val_accuracy: 0.6268 - 33s/epoch - 21ms/step
# Epoch 91/128
# 1563/1563 - 34s - loss: 0.1429 - accuracy: 0.9671 - val_loss: 7.7363 - val_accuracy: 0.6280 - 34s/epoch - 22ms/step
# Epoch 92/128
# 1563/1563 - 33s - loss: 0.1302 - accuracy: 0.9701 - val_loss: 7.9776 - val_accuracy: 0.6222 - 33s/epoch - 21ms/step
# Epoch 93/128
# 1563/1563 - 33s - loss: 0.1358 - accuracy: 0.9691 - val_loss: 8.0635 - val_accuracy: 0.6241 - 33s/epoch - 21ms/step
# Epoch 94/128
# 1563/1563 - 35s - loss: 0.1424 - accuracy: 0.9684 - val_loss: 8.0942 - val_accuracy: 0.6258 - 35s/epoch - 22ms/step
# Epoch 95/128
# 1563/1563 - 33s - loss: 0.1556 - accuracy: 0.9664 - val_loss: 8.2114 - val_accuracy: 0.6232 - 33s/epoch - 21ms/step
# Epoch 96/128
# Epoch 97/128
# 1563/1563 - 34s - loss: 0.1367 - accuracy: 0.9702 - val_loss: 8.2248 - val_accuracy: 0.6278 - 34s/epoch - 21ms/step
# Epoch 98/128
# 1563/1563 - 35s - loss: 0.1367 - accuracy: 0.9692 - val_loss: 8.5469 - val_accuracy: 0.6211 - 35s/epoch - 23ms/step
# Epoch 99/128
# 1563/1563 - 34s - loss: 0.1311 - accuracy: 0.9717 - val_loss: 8.4954 - val_accuracy: 0.6247 - 34s/epoch - 22ms/step
# Epoch 100/128
# 1563/1563 - 36s - loss: 0.1490 - accuracy: 0.9679 - val_loss: 8.4076 - val_accuracy: 0.6235 - 36s/epoch - 23ms/step
# Epoch 101/128
# 1563/1563 - 34s - loss: 0.1282 - accuracy: 0.9721 - val_loss: 8.7659 - val_accuracy: 0.6235 - 34s/epoch - 22ms/step
# Epoch 102/128
# 1563/1563 - 33s - loss: 0.1491 - accuracy: 0.9693 - val_loss: 8.7413 - val_accuracy: 0.6195 - 33s/epoch - 21ms/step
# Epoch 103/128
# 1563/1563 - 35s - loss: 0.1378 - accuracy: 0.9704 - val_loss: 8.7240 - val_accuracy: 0.6247 - 35s/epoch - 23ms/step
# Epoch 104/128
# 1563/1563 - 33s - loss: 0.1400 - accuracy: 0.9707 - val_loss: 8.7854 - val_accuracy: 0.6237 - 33s/epoch - 21ms/step
# Epoch 105/128
# 1563/1563 - 34s - loss: 0.1350 - accuracy: 0.9713 - val_loss: 9.1434 - val_accuracy: 0.6284 - 34s/epoch - 22ms/step
# Epoch 106/128
# 1563/1563 - 34s - loss: 0.1440 - accuracy: 0.9707 - val_loss: 9.1002 - val_accuracy: 0.6242 - 34s/epoch - 22ms/step
# Epoch 107/128
# 1563/1563 - 35s - loss: 0.1344 - accuracy: 0.9720 - val_loss: 9.2608 - val_accuracy: 0.6212 - 35s/epoch - 22ms/step
# Epoch 108/128
# 1563/1563 - 33s - loss: 0.1500 - accuracy: 0.9709 - val_loss: 9.3134 - val_accuracy: 0.6223 - 33s/epoch - 21ms/step
# Epoch 109/128
# 1563/1563 - 36s - loss: 0.1414 - accuracy: 0.9716 - val_loss: 9.3562 - val_accuracy: 0.6250 - 36s/epoch - 23ms/step
# Epoch 110/128
# 1563/1563 - 35s - loss: 0.1442 - accuracy: 0.9715 - val_loss: 9.4693 - val_accuracy: 0.6248 - 35s/epoch - 23ms/step
# Epoch 111/128
# 1563/1563 - 36s - loss: 0.1415 - accuracy: 0.9715 - val_loss: 9.5036 - val_accuracy: 0.6283 - 36s/epoch - 23ms/step
# Epoch 112/128
# 1563/1563 - 35s - loss: 0.1316 - accuracy: 0.9741 - val_loss: 9.7942 - val_accuracy: 0.6151 - 35s/epoch - 22ms/step
# Epoch 113/128
# 1563/1563 - 33s - loss: 0.1504 - accuracy: 0.9711 - val_loss: 9.8728 - val_accuracy: 0.6175 - 33s/epoch - 21ms/step
# Epoch 114/128
# 1563/1563 - 34s - loss: 0.1375 - accuracy: 0.9726 - val_loss: 10.0550 - val_accuracy: 0.6176 - 34s/epoch - 22ms/step
# Epoch 115/128
# 1563/1563 - 33s - loss: 0.1343 - accuracy: 0.9736 - val_loss: 9.9696 - val_accuracy: 0.6239 - 33s/epoch - 21ms/step
# Epoch 116/128
# 1563/1563 - 36s - loss: 0.1438 - accuracy: 0.9722 - val_loss: 10.0496 - val_accuracy: 0.6237 - 36s/epoch - 23ms/step
# Epoch 117/128
# 1563/1563 - 34s - loss: 0.1490 - accuracy: 0.9718 - val_loss: 10.2649 - val_accuracy: 0.6266 - 34s/epoch - 22ms/step
# Epoch 118/128
# 1563/1563 - 34s - loss: 0.1468 - accuracy: 0.9723 - val_loss: 10.3623 - val_accuracy: 0.6168 - 34s/epoch - 22ms/step
# Epoch 119/128
# 1563/1563 - 33s - loss: 0.1329 - accuracy: 0.9746 - val_loss: 10.5000 - val_accuracy: 0.6264 - 33s/epoch - 21ms/step
# Epoch 120/128
# 1563/1563 - 33s - loss: 0.1433 - accuracy: 0.9739 - val_loss: 10.4443 - val_accuracy: 0.6170 - 33s/epoch - 21ms/step
# Epoch 121/128
# 1563/1563 - 35s - loss: 0.1463 - accuracy: 0.9720 - val_loss: 10.4010 - val_accuracy: 0.6251 - 35s/epoch - 22ms/step
# Epoch 122/128
# 1563/1563 - 33s - loss: 0.1545 - accuracy: 0.9711 - val_loss: 10.5476 - val_accuracy: 0.6205 - 33s/epoch - 21ms/step
# Epoch 123/128
# 1563/1563 - 34s - loss: 0.1331 - accuracy: 0.9751 - val_loss: 10.6370 - val_accuracy: 0.6167 - 34s/epoch - 22ms/step
# Epoch 124/128
# 1563/1563 - 33s - loss: 0.1400 - accuracy: 0.9744 - val_loss: 11.0415 - val_accuracy: 0.6186 - 33s/epoch - 21ms/step
# Epoch 125/128
# 1563/1563 - 36s - loss: 0.1538 - accuracy: 0.9722 - val_loss: 11.0438 - val_accuracy: 0.6227 - 36s/epoch - 23ms/step
# Epoch 126/128
# 1563/1563 - 35s - loss: 0.1411 - accuracy: 0.9739 - val_loss: 11.1695 - val_accuracy: 0.6287 - 35s/epoch - 23ms/step
# Epoch 127/128
# 1563/1563 - 33s - loss: 0.1460 - accuracy: 0.9740 - val_loss: 11.2585 - val_accuracy: 0.6272 - 33s/epoch - 21ms/step
# Epoch 128/128
# 1563/1563 - 32s - loss: 0.1448 - accuracy: 0.9737 - val_loss: 11.2569 - val_accuracy: 0.6218 - 32s/epoch - 21ms/step

# %% [markdown]
# 程式 4-4 (繪製訓練結果)

# %%
import matplotlib.pyplot as plt #匯入 Python 的 matplotlib繪圖套件來畫圖

#讀取 model.fit() 所產生的 history 資料
train_loss = history.history['loss']
val_loss = history.history['val_loss']


#繪製每週期的train error 以及 test error
epochs_range = range(1, EPOCHS + 1)

plt.figure(figsize=(10, 5))
plt.plot(epochs_range, train_loss, label='Train Loss')
plt.plot(epochs_range, val_loss, label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.title('Training and Test Error')
plt.legend()
plt.grid()
plt.show()
