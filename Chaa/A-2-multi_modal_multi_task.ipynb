# %% [markdown]
# 程式A-5

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.text \
    import text_to_word_sequence
from tensorflow.keras.preprocessing.sequence \
    import pad_sequences
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model
import numpy as np
import logging
tf.get_logger().setLevel(logging.ERROR)

EPOCHS = 20
MAX_WORDS = 8
EMBEDDING_WIDTH = 4

# 載入訓練集與測試集
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images,
                               test_labels) = mnist.load_data()

# 標準化資料
mean = np.mean(train_images)
stddev = np.std(train_images)
train_images = (train_images - mean) / stddev
test_images = (test_images - mean) / stddev
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# 程式A-6

# %%
1	# 定義一個建立問答題庫的函式
def create_question_answer(tokenizer, labels):
    text = []
    answers = np.zeros(len(labels))
    for i, label in enumerate(labels):
        question_num = i % 4
        if question_num == 0:
            text.append('lower half')
            if label < 5:
                answers[i] = 1.0
        elif question_num == 1:
            text.append('upper half')
            if label >= 5:
                answers[i] = 1.0
        elif question_num == 2:
            text.append('even number')
            if label % 2 == 0:
                answers[i] = 1.0
        elif question_num == 3:
            text.append('odd number')
            if label % 2 == 1:
                answers[i] = 1.0
    text = tokenizer.texts_to_sequences(text)
    text = pad_sequences(text)
    return text, answers

# 為訓練集與測試集樣本一一建立文字敘述
vocabulary = ['lower', 'upper', 'half', 'even', 'odd', 'number']
tokenizer = Tokenizer(num_words=MAX_WORDS)
tokenizer.fit_on_texts(vocabulary)
train_text, train_answers = create_question_answer(tokenizer,
                                                   train_labels)
test_text, test_answers = create_question_answer(tokenizer,
                                                 test_labels)

# %% [markdown]
# 程式A-7

# %%
# 以函數式API建立模型
image_input = Input(shape=(28, 28))
text_input = Input(shape=(2, ))

# 宣告各神經層
embedding_layer = Embedding(output_dim=EMBEDDING_WIDTH,
                            input_dim = MAX_WORDS)
lstm_layer = LSTM(8)
flatten_layer = Flatten()
concat_layer = Concatenate()
dense_layer = Dense(25,activation='relu')
class_output_layer = Dense(10, activation='softmax')
answer_output_layer = Dense(1, activation='sigmoid')

# 連接各神經層
embedding_output = embedding_layer(text_input)
lstm_output = lstm_layer(embedding_output)
flatten_output = flatten_layer(image_input)
concat_output = concat_layer([lstm_output, flatten_output])
dense_output = dense_layer(concat_output)
class_outputs = class_output_layer(dense_output)
answer_outputs = answer_output_layer(dense_output)

# 建構、訓練模型
model = Model([image_input, text_input], [class_outputs,
                                          answer_outputs])
model.compile(loss=['sparse_categorical_crossentropy',
                    'binary_crossentropy'], optimizer='adam',
                    metrics=['accuracy'],
                    loss_weights = [0.5, 0.5])
model.summary()
history = model.fit([train_images, train_text],
                    [train_labels, train_answers],
                    validation_data=([test_images, test_text],
                    [test_labels, test_answers]), epochs=EPOCHS,
                    batch_size=64, verbose=2, shuffle=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 2)]          0           []
#
#  embedding (Embedding)          (None, 2, 4)         32          ['input_2[0][0]']
#
#  input_1 (InputLayer)           [(None, 28, 28)]     0           []
#
#  lstm (LSTM)                    (None, 8)            416         ['embedding[0][0]']
#
#  flatten (Flatten)              (None, 784)          0           ['input_1[0][0]']
#
#  concatenate (Concatenate)      (None, 792)          0           ['lstm[0][0]',
#                                                                   'flatten[0][0]']
#
#  dense (Dense)                  (None, 25)           19825       ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 10)           260         ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 1)            26          ['dense[0][0]']
#
# ==================================================================================================
# Total params: 20,559
# Trainable params: 20,559
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/20
# 938/938 - 8s - loss: 0.5095 - dense_1_loss: 0.4209 - dense_2_loss: 0.5980 - dense_1_accuracy: 0.8764 - dense_2_accuracy: 0.6613 - val_loss: 0.4161 - val_dense_1_loss: 0.2828 - val_dense_2_loss: 0.5495 - val_dense_1_accuracy: 0.9191 - val_dense_2_accuracy: 0.7035 - 8s/epoch - 9ms/step
# Epoch 2/20
# 938/938 - 5s - loss: 0.3334 - dense_1_loss: 0.2390 - dense_2_loss: 0.4277 - dense_1_accuracy: 0.9314 - dense_2_accuracy: 0.7969 - val_loss: 0.3672 - val_dense_1_loss: 0.2251 - val_dense_2_loss: 0.5094 - val_dense_1_accuracy: 0.9338 - val_dense_2_accuracy: 0.7453 - 5s/epoch - 5ms/step
# Epoch 3/20
# 938/938 - 4s - loss: 0.2883 - dense_1_loss: 0.2074 - dense_2_loss: 0.3691 - dense_1_accuracy: 0.9402 - dense_2_accuracy: 0.8338 - val_loss: 0.3284 - val_dense_1_loss: 0.2202 - val_dense_2_loss: 0.4366 - val_dense_1_accuracy: 0.9356 - val_dense_2_accuracy: 0.7975 - 4s/epoch - 4ms/step
# Epoch 4/20
# 938/938 - 4s - loss: 0.2459 - dense_1_loss: 0.1892 - dense_2_loss: 0.3025 - dense_1_accuracy: 0.9455 - dense_2_accuracy: 0.8774 - val_loss: 0.2867 - val_dense_1_loss: 0.2187 - val_dense_2_loss: 0.3548 - val_dense_1_accuracy: 0.9360 - val_dense_2_accuracy: 0.8520 - 4s/epoch - 4ms/step
# Epoch 5/20
# 938/938 - 4s - loss: 0.2092 - dense_1_loss: 0.1787 - dense_2_loss: 0.2396 - dense_1_accuracy: 0.9475 - dense_2_accuracy: 0.9131 - val_loss: 0.2443 - val_dense_1_loss: 0.2044 - val_dense_2_loss: 0.2842 - val_dense_1_accuracy: 0.9415 - val_dense_2_accuracy: 0.8919 - 4s/epoch - 5ms/step
# Epoch 6/20
# 938/938 - 3s - loss: 0.1876 - dense_1_loss: 0.1715 - dense_2_loss: 0.2037 - dense_1_accuracy: 0.9500 - dense_2_accuracy: 0.9275 - val_loss: 0.2352 - val_dense_1_loss: 0.2049 - val_dense_2_loss: 0.2656 - val_dense_1_accuracy: 0.9388 - val_dense_2_accuracy: 0.9025 - 3s/epoch - 4ms/step
# Epoch 7/20
# 938/938 - 3s - loss: 0.1738 - dense_1_loss: 0.1624 - dense_2_loss: 0.1852 - dense_1_accuracy: 0.9521 - dense_2_accuracy: 0.9331 - val_loss: 0.2216 - val_dense_1_loss: 0.1930 - val_dense_2_loss: 0.2502 - val_dense_1_accuracy: 0.9438 - val_dense_2_accuracy: 0.9077 - 3s/epoch - 4ms/step
# Epoch 8/20
# 938/938 - 4s - loss: 0.1648 - dense_1_loss: 0.1562 - dense_2_loss: 0.1735 - dense_1_accuracy: 0.9543 - dense_2_accuracy: 0.9380 - val_loss: 0.2179 - val_dense_1_loss: 0.1900 - val_dense_2_loss: 0.2459 - val_dense_1_accuracy: 0.9466 - val_dense_2_accuracy: 0.9122 - 4s/epoch - 5ms/step
# Epoch 9/20
# 938/938 - 4s - loss: 0.1574 - dense_1_loss: 0.1504 - dense_2_loss: 0.1643 - dense_1_accuracy: 0.9548 - dense_2_accuracy: 0.9416 - val_loss: 0.2241 - val_dense_1_loss: 0.1922 - val_dense_2_loss: 0.2561 - val_dense_1_accuracy: 0.9475 - val_dense_2_accuracy: 0.9103 - 4s/epoch - 4ms/step
# Epoch 10/20
# 938/938 - 4s - loss: 0.1534 - dense_1_loss: 0.1470 - dense_2_loss: 0.1597 - dense_1_accuracy: 0.9565 - dense_2_accuracy: 0.9434 - val_loss: 0.2184 - val_dense_1_loss: 0.1922 - val_dense_2_loss: 0.2446 - val_dense_1_accuracy: 0.9428 - val_dense_2_accuracy: 0.9148 - 4s/epoch - 4ms/step
# Epoch 11/20
# 938/938 - 4s - loss: 0.1496 - dense_1_loss: 0.1431 - dense_2_loss: 0.1562 - dense_1_accuracy: 0.9576 - dense_2_accuracy: 0.9449 - val_loss: 0.2218 - val_dense_1_loss: 0.1968 - val_dense_2_loss: 0.2469 - val_dense_1_accuracy: 0.9429 - val_dense_2_accuracy: 0.9142 - 4s/epoch - 4ms/step
# Epoch 12/20
# 938/938 - 4s - loss: 0.1449 - dense_1_loss: 0.1389 - dense_2_loss: 0.1510 - dense_1_accuracy: 0.9587 - dense_2_accuracy: 0.9469 - val_loss: 0.2172 - val_dense_1_loss: 0.1956 - val_dense_2_loss: 0.2387 - val_dense_1_accuracy: 0.9445 - val_dense_2_accuracy: 0.9184 - 4s/epoch - 5ms/step
# Epoch 13/20
# 938/938 - 4s - loss: 0.1425 - dense_1_loss: 0.1357 - dense_2_loss: 0.1493 - dense_1_accuracy: 0.9597 - dense_2_accuracy: 0.9473 - val_loss: 0.2170 - val_dense_1_loss: 0.1926 - val_dense_2_loss: 0.2414 - val_dense_1_accuracy: 0.9444 - val_dense_2_accuracy: 0.9173 - 4s/epoch - 4ms/step
# Epoch 14/20
# 938/938 - 3s - loss: 0.1392 - dense_1_loss: 0.1330 - dense_2_loss: 0.1455 - dense_1_accuracy: 0.9603 - dense_2_accuracy: 0.9480 - val_loss: 0.2146 - val_dense_1_loss: 0.1901 - val_dense_2_loss: 0.2390 - val_dense_1_accuracy: 0.9454 - val_dense_2_accuracy: 0.9197 - 3s/epoch - 4ms/step
# Epoch 15/20
# 938/938 - 4s - loss: 0.1356 - dense_1_loss: 0.1293 - dense_2_loss: 0.1420 - dense_1_accuracy: 0.9615 - dense_2_accuracy: 0.9494 - val_loss: 0.2067 - val_dense_1_loss: 0.1829 - val_dense_2_loss: 0.2306 - val_dense_1_accuracy: 0.9488 - val_dense_2_accuracy: 0.9226 - 4s/epoch - 5ms/step
# Epoch 16/20
# 938/938 - 4s - loss: 0.1334 - dense_1_loss: 0.1271 - dense_2_loss: 0.1398 - dense_1_accuracy: 0.9621 - dense_2_accuracy: 0.9505 - val_loss: 0.2134 - val_dense_1_loss: 0.1927 - val_dense_2_loss: 0.2341 - val_dense_1_accuracy: 0.9449 - val_dense_2_accuracy: 0.9205 - 4s/epoch - 4ms/step
# Epoch 17/20
# 938/938 - 3s - loss: 0.1308 - dense_1_loss: 0.1250 - dense_2_loss: 0.1366 - dense_1_accuracy: 0.9629 - dense_2_accuracy: 0.9516 - val_loss: 0.2171 - val_dense_1_loss: 0.1987 - val_dense_2_loss: 0.2355 - val_dense_1_accuracy: 0.9440 - val_dense_2_accuracy: 0.9226 - 3s/epoch - 4ms/step
# Epoch 18/20
# 938/938 - 5s - loss: 0.1300 - dense_1_loss: 0.1233 - dense_2_loss: 0.1366 - dense_1_accuracy: 0.9632 - dense_2_accuracy: 0.9509 - val_loss: 0.2277 - val_dense_1_loss: 0.2022 - val_dense_2_loss: 0.2532 - val_dense_1_accuracy: 0.9442 - val_dense_2_accuracy: 0.9174 - 5s/epoch - 5ms/step
# Epoch 19/20
# 938/938 - 4s - loss: 0.1274 - dense_1_loss: 0.1210 - dense_2_loss: 0.1337 - dense_1_accuracy: 0.9631 - dense_2_accuracy: 0.9523 - val_loss: 0.2117 - val_dense_1_loss: 0.1948 - val_dense_2_loss: 0.2286 - val_dense_1_accuracy: 0.9438 - val_dense_2_accuracy: 0.9246 - 4s/epoch - 4ms/step
# Epoch 20/20
# 938/938 - 4s - loss: 0.1260 - dense_1_loss: 0.1194 - dense_2_loss: 0.1327 - dense_1_accuracy: 0.9646 - dense_2_accuracy: 0.9519 - val_loss: 0.2264 - val_dense_1_loss: 0.2003 - val_dense_2_loss: 0.2525 - val_dense_1_accuracy: 0.9441 - val_dense_2_accuracy: 0.9156 - 4s/epoch - 4ms/step
